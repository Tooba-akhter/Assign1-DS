# %%
fname = input("Input your First Name : ")
lname = input("Input your Last Name : ")
print ( lname + " " + fname)
# Out:
# Input your First Name :  TOOBA
# Input your Last Name :  ARAIN
# ARAIN TOOBA
